# %% [markdown]
# # Data Analysis Case Study
# ## Potential Strategies to Boost Ticket Sale in HOYTS Cinema
#
# **Problem**
# Assume you are in the role of an Analyst in the product development of the company. To help increase the volume of orders and customers purchasing movie tickets online, you need to analyze data of customers' booking history over the past years. From there, provide informative insights about customer behavior and corresponding recommendations.

# %% [markdown]
# > This is a capstone project I completed for self-learning Python for Data Analysis based on my knowledge of R and Data Analysis. After many excuses for delaying, procastinating, I'm proud to be confident in Python now especially using Pandas, and Matplot.
#
# > There are many frameworks for data analysis. Framework provides a structured and systemetic approach for managing and analyzing data tasks/projects to ensure consistency, efficiency, and high quality work. The framework I use:
# Problem Definition => Data Collection => Data Transformation => Data Exploration => Sharing Insights
#
# > The project also trains my mindset and thinking in: analytical thinking, statistical thinking, and problem solving strategy.
#
# # 1. Define The Problem
# **Why?**
# - The objective of this task is to analyze user behavior in purchasing movie tickets over the past four years using data.
# - By gaining this understanding, we can develop insights to implement effective strategies to increase sales and the number of buyers in the coming years.
#
# **Who?**
# - Internal: Departments and/or staffs involves in ticket purchasing process? Sale, marketing, web development team, customer service
# - External: Who is our customers?
# - Location: which city/province/area
# - Profile: new customer, old customer, activated customer,..
# - Demographic: gender (male/femail), age, education, marriage or not,..
#
# **What?**
# - Analyze ticket purchasing behavior using website and mobile app
#
# **Which**
# Which element or factor  does customers use duing online ticket purchasing process?
# - Product: tickets
# - Device: phone, website
# - Payment options: cash, card, bank transfer, e-wallet
# - Price
# - Promotion / Discount
#
# **When**
# When do customers often buy tickets?
# - Year, month, day, hour
# - Holiday, event, new movie
#
# **How**
# How did customers use the product?
# - Customer experience: Good, bad
# + Feedback
# + %Successful ticket purchases
# + %Customer retention
# - Purchasing process
# + Total time completing ticket purchase
# + Time taken for each step in the process. Any bottle-necks? Any step that customer faced frustration?

# %% [markdown]
# # 2. Disaggregate The Problem
# Based on the problem definition, we can create a Logic Tree
#
#  ![Logic Tree](https://i.ibb.co/qmGBj8k/movie-ticket.jpg)

# %% [markdown]
# ## 2.1 Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
df_customer = pd.read_csv("D:/Git DucD Data/SQLplaygroundDataAnalysis/Capstone project/Dataset/customer.csv")
df_campaign = pd.read_csv("D:/Git DucD Data/SQLplaygroundDataAnalysis/Capstone project/Dataset/campaign.csv")
df_device = pd.read_csv("D:/Git DucD Data/SQLplaygroundDataAnalysis/Capstone project/Dataset/device_detail.csv")
df_sales = pd.read_csv("D:/Git DucD Data/SQLplaygroundDataAnalysis/Capstone project/Dataset/sales.csv")
df_status = pd.read_csv("D:/Git DucD Data/SQLplaygroundDataAnalysis/Capstone project/Dataset/status_detail.csv")
df_ticket = pd.read_csv("D:/Git DucD Data/SQLplaygroundDataAnalysis/Capstone project/Dataset/ticket_history.csv")

# %% [markdown]
# ## 2.2 Clean Data

# %% [markdown]
# ### 2.1 Data type, NULL value, duplicate values**

# %%
#CUSTOMER table
#convert DOB type to datetime from object type
df_customer.info()
df_customer['dob'] = pd.to_datetime(df_customer['dob'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52054 entries, 0 to 52053
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     52054 non-null  int64
#  1   usergender  52054 non-null  int64
#  2   dob         52054 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 1.2+ MB

# %%
#to check duplicate, we unique count records and compare with the total record number
df_customer.nunique()
# Out:
# user_id       52054
# usergender        3
# dob            9115
# dtype: int64

# %%
#CAMPAIGN table
df_campaign.info()
df_campaign.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   campaign_code  105 non-null    int64
#  1   campaign_type  105 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 1.8+ KB
# campaign_code    105
# campaign_type      3
# dtype: int64

# %%
#DEVICE table
df_device.info()

#from the result, we can see some null numbers in model 55519 comparing to other columns
#before making decision on how to handle we need to check %null value on total
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55639 entries, 0 to 55638
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   device_id  55637 non-null  object
#  1   model      55519 non-null  object
#  2   platform   55639 non-null  object
# dtypes: object(3)
# memory usage: 1.3+ MB

# %%
def calc_null_rate(df):
    """check NULL rate of each column
    """
    newdf = df.isnull().sum().to_frame('null count')
    newdf [['null rate']] = newdf[['null count']] / len(df)
    return newdf.sort_values(by=['null rate'], ascending=False)

# %%
#calculate null and null rate
calc_null_rate(df_device)
# Out:
#            null count  null rate
# model             120   0.002157
# device_id           2   0.000036
# platform            0   0.000000

# %%
#[Duc note] for data analysis, delete 2 records that have null value has minor impact of our analysis.
#change NULL value in model to unknown string
df_device = df_device.fillna({'model' : 'unknown'})

#delete 2 NULL records in devicemodel
df_device = df_device[df_device['device_id'].notna()]

calc_null_rate(df_device)
# Out:
#            null count  null rate
# device_id           0        0.0
# model               0        0.0
# platform            0        0.0

# %%
#STATUS table
df_status
df_status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   status_id    8 non-null      int64
#  1   status_name  8 non-null      object
#  2   description  8 non-null      object
#  3   error_group  7 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 388.0+ bytes

# %%
#TICKET HISTORY table (fact)
#[Duc] as it's a fact table - transaction records, we need to review more throughly
df_ticket
df_ticket.info()
df_ticket.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67522 entries, 0 to 67521
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ticket_id          67522 non-null  object
#  1   customer_id        67522 non-null  int64
#  2   paying_method      67522 non-null  object
#  3   theater_name       67522 non-null  float64
#  4   device_id          67522 non-null  object
#  5   original_price     67522 non-null  float64
#  6   discount_value     67522 non-null  float64
#  7   final_price        67522 non-null  float64
#  8   time               67522 non-null  object
#  9   status_id          67522 non-null  int64
#  10  mkt_campaign_code  67522 non-null  int64
#  11  movie_name         67522 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 6.2+ MB
#                           ticket_id  customer_id paying_method  theater_name  \
# ...

# %%
#Time table is in object/text. It should be time
df_ticket['time'] = pd.to_datetime(df_ticket['time'])

# %%
df_ticket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67522 entries, 0 to 67521
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ticket_id          67522 non-null  object
#  1   customer_id        67522 non-null  int64
#  2   paying_method      67522 non-null  object
#  3   theater_name       67522 non-null  float64
#  4   device_id          67522 non-null  object
#  5   original_price     67522 non-null  float64
#  6   discount_value     67522 non-null  float64
#  7   final_price        67522 non-null  float64
#  8   time               67522 non-null  datetime64[ns]
#  9   status_id          67522 non-null  int64
#  10  mkt_campaign_code  67522 non-null  int64
#  11  movie_name         67522 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(4)
# memory usage: 6.2+ MB

# %%
calc_null_rate(df_ticket)
# Out:
#                    null count  null rate
# ticket_id                   0        0.0
# customer_id                 0        0.0
# paying_method               0        0.0
# theater_name                0        0.0
# device_id                   0        0.0
# original_price              0        0.0
# discount_value              0        0.0
# final_price                 0        0.0
# time                        0        0.0
# status_id                   0        0.0
# mkt_campaign_code           0        0.0
# movie_name                  0        0.0

# %%
df_ticket.nunique()
#total records: 67522 ; there are duplicate records
# Out:
# ticket_id            67515
# customer_id          50512
# paying_method            4
# theater_name           114
# device_id            53352
# original_price        1003
# discount_value         176
# final_price           1438
# time                 67515
# status_id                8
# mkt_campaign_code      103
# movie_name             316
# dtype: int64

# %%
#check duplicate
df_dup = df_ticket[df_ticket.duplicated(keep=False)]

df_dup
# Out:
#                               ticket_id  customer_id paying_method  \
# 24027  de40b1921df46e455e426a6dac047d4d       105710       balance
# 24028  de40b1921df46e455e426a6dac047d4d       105710       balance
# 24111  763e20c9c1136c5c06d9a960fac9dae6       143762   credit card
# 24112  763e20c9c1136c5c06d9a960fac9dae6       143762   credit card
# 24139  a6062e2443611f0d65727c5469fe89a2       109678  bank account
# 24140  a6062e2443611f0d65727c5469fe89a2       109678  bank account
# 24189  d0559f718b50247ad965767ea9be3ab3       131072       balance
# 24190  d0559f718b50247ad965767ea9be3ab3       131072       balance
# 24422  2cdf7de498105664abbd91bc30bb4438       100194  bank account
# 24423  2cdf7de498105664abbd91bc30bb4438       100194  bank account
# 24558  5f377be63fca730d5b5d12e06ac3f05d       110085   credit card
# 24559  5f377be63fca730d5b5d12e06ac3f05d       110085   credit card
# 26520  0b63dae2c17a77b9cab0521dd12c3f88       113174   credit card
# ...

# %%
#We have records that have the same information ??
df_ticket.drop_duplicates(inplace=True) #remove duplicate. default keep the first one. inplace true to modify the original data frame

# %%
df_ticket.nunique()
df_ticket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67515 entries, 0 to 67521
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ticket_id          67515 non-null  object
#  1   customer_id        67515 non-null  int64
#  2   paying_method      67515 non-null  object
#  3   theater_name       67515 non-null  float64
#  4   device_id          67515 non-null  object
#  5   original_price     67515 non-null  float64
#  6   discount_value     67515 non-null  float64
#  7   final_price        67515 non-null  float64
#  8   time               67515 non-null  datetime64[ns]
#  9   status_id          67515 non-null  int64
#  10  mkt_campaign_code  67515 non-null  int64
#  11  movie_name         67515 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# ### 2.2 Join tables

# %%
#[Duc]join all table to give us a systematic view of all our data instead of silo tables
#from tickets we join with the other tables
df_join_customer = pd.merge(df_ticket, df_customer, how = 'left',  left_on='customer_id', right_on='user_id')
df_join_campaign = pd.merge(df_join_customer, df_campaign, how = 'left', left_on='mkt_campaign_code', right_on='campaign_code')
df_join_status = pd.merge(df_join_campaign, df_status, how = 'left', on='status_id')
df_join_all = pd.merge(df_join_status, df_device, how = 'left', on='device_id')

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  9f2da3491b42b7599065ac102bdcb4c2       100004   credit card          33.0
# 1  8607fe9d2d12e14d711c49ae1204de29       118325   credit card          20.0
#
#                           device_id  original_price  discount_value  \
# 0  3cac5d2e2eb76525aecea5c2ab46b3d9            4.54            1.28
# 1  9d6100d117d5f0aa65fc29b6d9edd9f7            3.09            0.00
#
#    final_price                    time  status_id  ...  user_id usergender  \
# 0         3.26 2019-11-16 13:28:24.970          1  ...   100004          1
# 1         3.09 2019-11-13 18:12:03.260          1  ...   118325          2
#
#          dob  campaign_code    campaign_type  status_name  \
# 0 1989-02-25        25690.0  direct discount      SUCCESS
# 1 1992-10-03            NaN              NaN      SUCCESS
#
#               description error_group       model platform
# 0  Transaction successful         NaN  iPhone10,2   mobile
# ...

# %%
calc_null_rate(df_join_all)
# Out:
#                    null count  null rate
# error_group             57746   0.834528
# campaign_code           33711   0.487181
# campaign_type           33711   0.487181
# model                     178   0.002572
# platform                  178   0.002572
# ticket_id                   0   0.000000
# original_price              0   0.000000
# device_id                   0   0.000000
# theater_name                0   0.000000
# paying_method               0   0.000000
# customer_id                 0   0.000000
# discount_value              0   0.000000
# time                        0   0.000000
# final_price                 0   0.000000
# usergender                  0   0.000000
# user_id                     0   0.000000
# movie_name                  0   0.000000
# mkt_campaign_code           0   0.000000
# status_id                   0   0.000000
# dob                         0   0.000000
# status_name                 0   0.000000
# description                 0   0.000000

# %% [markdown]
# **Analysis:**
# Looking at the attributes that have NULL,
# - error_group: We can ignore 'error_group' because it identifies if a records belong to any error_group. The transactions succeeded, and they had no errors.
# - campaign_code: Some orders were completed without discount campaign. Hence, the campaign_code & campaign_type are empty.
# - campaign_type: Same as the above.
# - model: Some orders could not find device_id & platform. The reason is unknown. However, the null rate is very low (~0.002) which won't have big impact in our calculation. We can map to unknown for tracking later.
# - platform: Same as the above.

# %%
df_join_all[df_join_all['error_group'].isnull()]
# Out:
#                               ticket_id  customer_id paying_method  \
# 0      9f2da3491b42b7599065ac102bdcb4c2       100004   credit card
# 1      8607fe9d2d12e14d711c49ae1204de29       118325   credit card
# 2      3b6145254e74306bfa15e359ee325512       115177  bank account
# 3      882a93bb56d6b2005c55216e6f4b64e2       116901  bank account
# 4      f3eb7c056b38244d23eed5e4cb019a44       135362   credit card
# ...                                 ...          ...           ...
# 69191  822a4b093b79bc8f01e3f4428376a847       118559    debit card
# 69192  fda2a0dbc302a132ab2a890511f64921       118783    debit card
# 69193  cd01413c6a2b85ecf0e0083393fbddfc       121610   credit card
# 69194  311f201448bbadfaf229f0457fd3652a       125872       balance
# 69195  fa02928a3c9b3d8fd071e6533db32316       134359   credit card
#
#        theater_name                         device_id  original_price  \
# 0              33.0  3cac5d2e2eb76525aecea5c2ab46b3d9            4.54
# ...

# %%
#replace null with unknown text to prevent errors
df_join_all = df_join_all.fillna('unknown')

# %%
calc_null_rate(df_join_all)
# Out:
#                    null count  null rate
# ticket_id                   0        0.0
# customer_id                 0        0.0
# paying_method               0        0.0
# theater_name                0        0.0
# device_id                   0        0.0
# original_price              0        0.0
# discount_value              0        0.0
# final_price                 0        0.0
# time                        0        0.0
# status_id                   0        0.0
# mkt_campaign_code           0        0.0
# movie_name                  0        0.0
# user_id                     0        0.0
# usergender                  0        0.0
# dob                         0        0.0
# campaign_code               0        0.0
# campaign_type               0        0.0
# status_name                 0        0.0
# description                 0        0.0
# error_group                 0        0.0
# model                       0        0.0
# platform                    0        0.0

# %% [markdown]
# ### 2.3 View all values  of each column

# %%
df_join_all.nunique().sort_values(ascending=False)
# Out:
# ticket_id            67515
# time                 67515
# device_id            53352
# customer_id          50512
# user_id              50512
# dob                   9000
# final_price           1438
# model                 1216
# original_price        1003
# movie_name             316
# discount_value         176
# theater_name           114
# campaign_code          103
# mkt_campaign_code      103
# description              8
# status_id                8
# status_name              8
# paying_method            4
# error_group              4
# campaign_type            4
# usergender               3
# platform                 3
# dtype: int64

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  9f2da3491b42b7599065ac102bdcb4c2       100004   credit card          33.0
# 1  8607fe9d2d12e14d711c49ae1204de29       118325   credit card          20.0
#
#                           device_id  original_price  discount_value  \
# 0  3cac5d2e2eb76525aecea5c2ab46b3d9            4.54            1.28
# 1  9d6100d117d5f0aa65fc29b6d9edd9f7            3.09            0.00
#
#    final_price                    time  status_id  ...  user_id usergender  \
# 0         3.26 2019-11-16 13:28:24.970          1  ...   100004          1
# 1         3.09 2019-11-13 18:12:03.260          1  ...   118325          2
#
#          dob  campaign_code    campaign_type status_name  \
# 0 1989-02-25        25690.0  direct discount     SUCCESS
# 1 1992-10-03        unknown          unknown     SUCCESS
#
#               description error_group       model platform
# 0  Transaction successful     unknown  iPhone10,2   mobile
# ...

# %%
df_join_all.theater_name.unique()
# Out:
# array([ 33.,  20., 113.,  53., 103.,  81.,  76.,  77.,  34.,  16.,   7.,
#         87.,  57.,   8.,  74.,  50.,  42.,  75.,  51.,  49.,  83.,  67.,
#         66.,  43.,  61.,  64.,  11.,   9.,  19.,  52.,  60.,  47.,  90.,
#         98.,   6.,  95.,  96.,  78.,  35.,  46.,  27., 104.,  17.,  94.,
#          3.,  70.,  91.,  36.,  63.,  56.,  39.,  84.,  44.,  32.,  10.,
#        112.,  13.,  80.,  55.,  14.,  31.,  12.,  54.,  85., 109.,  18.,
#         37.,  93., 102., 110., 100., 108.,  45.,  29.,  79., 106., 101.,
#         24., 107.,  72.,   2., 105.,  59.,  21.,  38.,  48.,  25.,  73.,
#         62.,  41.,  40.,   4.,  26.,  88.,  65.,  28.,  69.,  30.,  15.,
#         89.,  71.,  92., 111.,  99.,  82.,   5., 114.,  86.,  97.,  23.,
#        115.,  22.,  58.,  68.])

# %% [markdown]
# **Analysis** The names of the theaters are in ID. Missing theaters table. Also, the data type should be int not float

# %%
df_join_all['theater_name'] = df_join_all['theater_name'].astype(int)

# %%
#List out values of the table
specific_cols = ['description', 'status_name', 'paying_method', 'error_group', 'campaign_type', 'usergender', 'platform']
for cols in specific_cols:
    print(cols + ' : ', df_join_all[cols].unique().astype(str))
    print('-------------------------')
# Out:
# description :  ['Transaction successful'
#  'Insufficient funds in customer account. Please add more funds and try the transaction again.'
#  'Payment failed' 'An error occurred. Please try again later.'
#  'Password locked due to multiple incorrect attempts. Choose Forgot Password to unlock.'
#  'Payment overdue' 'Transaction temporarily limited'
#  'Please KYC to proceed with transactions']
# -------------------------
# status_name :  ['SUCCESS' 'LOW_BALANCE' 'FAILED_CHARGE' 'INVALID_BANK'
#  'WRONG_PIN_EXCEEDED' 'INVALID_TIME' 'TRANSACTION_LIMITED'
#  'KYC_REQUIRED_USER']
# -------------------------
# paying_method :  ['credit card' 'bank account' 'debit card' 'balance']
# -------------------------
# error_group :  ['unknown' 'customer' 'external' 'internal']
# -------------------------
# campaign_type :  ['direct discount' 'unknown' 'lixi' 'voucher']
# -------------------------
# usergender :  ['1' '2' '0']
# -------------------------
# platform :  ['mobile' 'website' 'unknown']
# ...

# %% [markdown]
# We also map user genders from number 0,1,3 to Male, Female, Not known

# %%
#Change usergender to string and mapping with male, female, not verify
df_join_all['usergender'] = df_join_all['usergender'].astype(str)
df_join_all['usergender'] = df_join_all['usergender'].replace(to_replace='1', value='Male')
df_join_all['usergender'] = df_join_all['usergender'].replace(to_replace='2', value='Female')
df_join_all['usergender'] = df_join_all['usergender'].replace(to_replace='0', value='Not verify')


#Change dob date type from str to datetime for calculation later
df_join_all['dob'] = pd.to_datetime(df_join_all['dob'])

# %% [markdown]
# # 3. Analyze
# ## 3.1 Customer Portrait
# ### Age and gender distribution

# %%
from datetime import datetime

# Calculate user age
current_date = datetime.now()

# %%
df_join_all['age day'] = (current_date - df_join_all['dob']).dt.days #number days
df_join_all['age'] = df_join_all['age day'] /365.25
df_join_all['age'] = df_join_all['age'].astype(int) #because default was float type

# %%
df_join_all.head(2)
# Out:
#                           ticket_id  customer_id paying_method  theater_name  \
# 0  9f2da3491b42b7599065ac102bdcb4c2       100004   credit card            33
# 1  8607fe9d2d12e14d711c49ae1204de29       118325   credit card            20
#
#                           device_id  original_price  discount_value  \
# 0  3cac5d2e2eb76525aecea5c2ab46b3d9            4.54            1.28
# 1  9d6100d117d5f0aa65fc29b6d9edd9f7            3.09            0.00
#
#    final_price                    time  status_id  ...        dob  \
# 0         3.26 2019-11-16 13:28:24.970          1  ... 1989-02-25
# 1         3.09 2019-11-13 18:12:03.260          1  ... 1992-10-03
#
#   campaign_code    campaign_type status_name             description  \
# 0       25690.0  direct discount     SUCCESS  Transaction successful
# 1       unknown          unknown     SUCCESS  Transaction successful
#
#   error_group       model platform age day age
# 0     unknown  iPhone10,2   mobile   13058  35
# ...

# %%
#Get customers list including age, dob, and gender
df_cus = df_join_all.drop_duplicates(subset=['customer_id']) [['customer_id', 'age', 'dob', 'usergender']] #drop duplicates based on a customer_id; Then select specific columns

# %%
df_cus.head(5)

# %%
#Plot Customer Age Distribution
plt.figure(figsize=(8,4))
df_cus['age'].hist(bins = 30, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Ages')
plt.ylabel('#Customers')
# Out:
# Text(0, 0.5, '#Customers')

# %% [markdown]
# From the graph, the majority of our customers are between 21 to 39 years old which majority of them are in their 30.
#
# We also have some outliners especially in the 50s rage which requires further investigation

# %% [markdown]
# After grouping by gender, we can see the outliners (~50 age) belong to Not Verify gender.

# %%
# Analyze the Not verify group in detail
df_gen = df_cus.groupby('usergender').agg(
    total = ('customer_id', 'count')
    ).sort_values(by='total', ascending=False).reset_index()

df_gen
# Out:
#    usergender  total
# 0        Male  24401
# 1      Female  23770
# 2  Not verify   2341

# %%
#Visualize
plt.figure(figsize=(13,4))

#Customer Gender Distribution
##data
male_age = df_cus[df_cus['usergender'] == 'Male']['age']
female_age = df_cus['age'][df_cus['usergender'] == 'Female']
unknown_age = df_cus['age'][df_cus['usergender'] == 'Not verify']

##plot 1
ax1 = plt.subplot(1, 2, 1)
plt.hist(male_age, bins=30, alpha = 0.3, color='skyblue', label='Male')
plt.hist(female_age, bins=30, alpha = 0.3, color='salmon', label='Female')
plt.hist(unknown_age, bins=30, alpha = 0.3, color='limegreen', label='Not Verify')

##label 1
plt.title('Gender Distribution by Age ')
plt.xlabel('Ages')
plt.ylabel('#Customers')
plt.legend()

##plot 2
ax2 = plt.subplot(1, 2, 2)
plt.pie(df_gen['total'], labels = df_gen['usergender'], colors=['skyblue', 'salmon', 'limegreen'], autopct='%1.0f%%', startangle=90) #display percentage% and angle at 90degree
plt.title('Gender Distribution')
plt.show()

# %%
df_cus[df_cus['usergender'] == 'Not verify'].groupby('age').agg(
    number = ('customer_id', 'count')).reset_index().sort_values(by='number', ascending=False).head(5)
# Out:
#     age  number
# 31   54    1730
# 8    30      68
# 6    28      63
# 5    27      48
# 9    31      46

# %% [markdown]
# **Notes**
# The customer group of "Not verify" is 5%. The reason could be:
# - Users only enter DOB after verifying his account, and enter info in his profile.
# - If user did not enter dob, the system will automatically fill dob as 1970 -> 54 years old

# %% [markdown]
# ### Age group distribution

# %%
df_cus.head
# Out:
# <bound method NDFrame.head of        customer_id  age        dob usergender
# 0           100004   35 1989-02-25       Male
# 1           118325   32 1992-10-03     Female
# 2           115177   27 1997-07-01     Female
# 3           116901   28 1996-01-06     Female
# 4           135362   35 1989-05-03       Male
# ...            ...  ...        ...        ...
# 69189       101169   31 1993-08-17       Male
# 69190       114959   32 1992-11-16       Male
# 69191       118559   54 1970-01-01       Male
# 69193       121610   33 1991-10-01       Male
# 69194       125872   30 1994-07-29       Male
#
# [50512 rows x 4 columns]>

# %%
#Split ages by grouping to baby boomer, gen x, gen y, gen z
df_cus['age_generation'] = df_cus['dob'].apply(lambda x: 'baby boomer' if x.year < 1965 
                                               else 'gen X' if x.year < 1981 else
                                               'gen Y' if x.year < 1997 else 'gen Z')

# %%
df_gen_group = (
    df_cus[df_cus['usergender'] != 'Not verify']
    .groupby('age_generation')
    .agg(total_count = ('customer_id', 'count'))
    .sort_values('total_count',ascending=False)
    .reset_index()  
)

# %%
df_gen_group
# Out:
#   age_generation  total_count
# 0          gen Y        35877
# 1          gen Z         9804
# 2          gen X         2162
# 3    baby boomer          328

# %%
#Plot Age Group Distribution
plt.figure(figsize=(13,4))

#plot1
ax1 = plt.subplot(1,2,1)
df_cus['age'][df_cus['usergender'] != 'Not verify'].hist(bins = 30, color='skyblue')
plt.title('Age distribution')
plt.xlabel('ages')
plt.ylabel('#customers')

#title1
plt.title('Age Distribution of Verified Customers')
plt.xlabel('Ages')
plt.ylabel('#Customers')
plt.legend()

##plot2
ax2 = plt.subplot(1, 2, 2)
plt.pie(df_gen_group['total_count'], 
        labels = None, 
        colors=['skyblue', 'salmon', 'limegreen', 'orange'], 
        autopct='%1.0f%%', startangle=90,
        pctdistance=1.1)
plt.title('Age Group Distribution')
plt.legend(df_gen_group['age_generation'], loc = 4)
plt.show()
# Out:
# C:\Users\DucD-PC-Z390\AppData\Local\Temp\ipykernel_47888\2051501493.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## 3.2 Time Series Data - When did customers buy tickets?

# %% [markdown]
# ### Trend by month

# %%
#Create time columns
df_join_all['month'] = pd.to_datetime(df_join_all['time']).dt.month
df_join_all['name_day'] = pd.to_datetime(df_join_all['time']).dt.day_name()
df_join_all['hour'] = pd.to_datetime(df_join_all['time']).dt.hour
df_join_all['year_month'] = df_join_all['time'].dt.strftime('%Y-%m')

# %%
#By Month
df_time_month = (
    df_join_all
    .groupby(df_join_all['year_month'])
    .agg(
        total_ticket = ('year_month', 'count')
    ).reset_index()
)

df_time_month.head(5)
# Out:
#   year_month  total_ticket
# 0    2019-01          2389
# 1    2019-02          2018
# 2    2019-03          1290
# 3    2019-04          4346
# 4    2019-05          4816

# %%
# Plot by month
plt.figure(figsize=(13,4))

plt.fill_between(df_time_month['year_month'], df_time_month['total_ticket']
                 , alpha = 0.5)
plt.xticks(rotation=90) #rotate x-label
plt.title('Tickets by Months')
plt.ylabel('#Sold tickets')
plt.show()

# %% [markdown]
# Between October 2019 and October 2020, there was a sharp decrease in the number of tickets sold. The numbers then rebounded and peaked in March 2021. However, sales declined again afterward, eventually dropping to zero.
#
# These trends can be explained by the lockdowns during the COVID-19 pandemic. During the lockdown period, businesses were closed, and people movement was restricted. As a result, there was a high demand for doing outdoor activities such as going to a cinema, leading to the peak in ticket sales in March 2021 after the lockdown was lifted. However, the government announced another lockdown, which halted all business activities until the end of 2021.
#
# Interestingly, our data is missing 4/2020 and 9/2021. It mean we did not have any data in this period

# %%
#Define the time period
start_date = '2019-01-01'
end_date = '2021-12-30'

#Create time range from the start and end date
date_range = pd.date_range(start = start_date, end=end_date, freq = 'MS')

#Extract time elements
list_month = date_range.month
list_month_name = date_range.strftime('%B')
list_year = date_range.year
list_year_month = date_range.strftime('%Y-%m')

#Create dataframe
dim_time = pd.DataFrame({
    'month_number' : list_month,
    'month_name' : list_month_name,
    'year_number' : list_year,
    'year_month' : list_year_month
})

# %%
dim_time.head(5)
# Out:
#    month_number month_name  year_number year_month
# 0             1    January         2019    2019-01
# 1             2   February         2019    2019-02
# 2             3      March         2019    2019-03
# 3             4      April         2019    2019-04
# 4             5        May         2019    2019-05

# %%
#Left join with df_join all to have complete time data
df_time_month_dim = (
    pd.merge(dim_time, df_join_all, how='left', on='year_month')
    .groupby('year_month')
    .agg(total_ticket = ('ticket_id','count'))
    .reset_index()
)

#Replace 0 ticket purchased with null to present 0 data in chart
df_time_month_dim.replace(0, np.nan, inplace=True)

# %%
#Redraw
plt.figure(figsize=(13,4))

plt.fill_between(df_time_month_dim['year_month'], df_time_month_dim['total_ticket'],
                 alpha = 0.5)
plt.xticks(rotation=90)
plt.title('Tickets by Months')
plt.ylabel('#Sold tickets')
plt.show()

# %% [markdown]
# ### Trend by week days

# %%
df_week_day = (
    df_join_all
    .groupby('name_day')
    .agg(total_ticket = ('ticket_id','count'))
    .reset_index()
)

# %%
df_week_day
# Out:
#     name_day  total_ticket
# 0     Friday         12514
# 1     Monday          6695
# 2   Saturday         15922
# 3     Sunday         12773
# 4   Thursday          8178
# 5    Tuesday          6026
# 6  Wednesday          7088

# %%
#Re-arrange week days in correct order from Mon - Sun
week_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df_week_day['name_day'] = pd.Categorical(df_week_day['name_day'], categories=week_order, ordered=True)
df_week_day.sort_values('name_day', inplace=True)

df_week_day
# Out:
#     name_day  total_ticket
# 1     Monday          6695
# 5    Tuesday          6026
# 6  Wednesday          7088
# 4   Thursday          8178
# 0     Friday         12514
# 2   Saturday         15922
# 3     Sunday         12773

# %%
#Redraw
plt.figure(figsize=(13,4))

plt.fill_between(df_week_day['name_day'], df_week_day['total_ticket'],
                 alpha = 0.5)
plt.xticks(rotation=90)
plt.title('Tickets by Week Days')
plt.ylabel('#Sold tickets')
plt.show()

# %% [markdown]
# In general, ticket sales were the highest on the weekend starting from Friday which increase steadily and peak at Satuday. Let's drill down 1 more level (by time)

# %% [markdown]
# ### Trend by hours

# %%
df_hour = (
    df_join_all
    .groupby('hour')
    .agg(
        total_ticket = ('ticket_id','count')
    ).reset_index()
)

# %%
#Plot Tickets Sold by Hours
plt.figure(figsize=(13,4))

plt.fill_between(df_hour['hour'], df_hour['total_ticket'], alpha=0.5)
x_values = [i for i in range(24)]
plt.xticks(x_values)
plt.title('Tickets Sold by Hours')
plt.xlabel('Hours')
plt.ylabel('#Sold tickets')
plt.show()

# %% [markdown]
# From 0AM to 5AM, the sales were low but there were still people bought and watched movies in this period. It began to raise gradually after 6AM, and a noticeable increase starting around 9AM till 11AM. It likely indicated increased customer activity during late mornings.
#
# It became stable from 12AM to 3PM and increased again after, reaching the peak around 19:00PM. Then it started to decline.

# %%
#Combine the 3 graphs into 1
plt.figure(figsize=(13,8))

#Plot1
ax1 = plt.subplot(2,1,1)
plt.fill_between(df_time_month_dim['year_month'], df_time_month_dim['total_ticket'],
                 alpha = 0.5)
plt.xticks(rotation=90)
plt.title('Tickets by Months')
plt.ylabel('#Sold tickets')

#Plot 2
ax2 = plt.subplot(2,2,3)
plt.fill_between(df_week_day['name_day'], df_week_day['total_ticket'],
                 alpha = 0.5)
plt.xticks(rotation=90)
plt.title('Tickets by Week Days')
plt.ylabel('#Sold tickets')

#Plot 3
ax3 = plt.subplot(2,2,4)
plt.fill_between(df_hour['hour'], df_hour['total_ticket'], alpha=0.5)
x_values = [i for i in range(24)]
plt.xticks(x_values)
plt.title('Tickets Sold by Hours')
plt.xlabel('Hours')
plt.ylabel('#Sold tickets')

plt.subplots_adjust(hspace = 1, top = 0.8)

plt.show()

# %% [markdown]
# ## 3.3 Factors Related To Customer's Purchasing Process

# %% [markdown]
# ### Payment platform

# %%
df_platform = (
    df_join_all
    .groupby('platform')
    .agg(total_ticket = ('ticket_id','count'))
    .reset_index()
)

# %%
df_platform
# Out:
#   platform  total_ticket
# 0   mobile         68514
# 1  unknown           178
# 2  website           504

# %%
#Plot Bar Chart
plt.figure(figsize=(8,4))

plt.barh(
    df_platform['platform'], df_platform['total_ticket']
)

for index, value in enumerate(df_platform['total_ticket']): #show values
    plt.text(value, index, str(value))

plt.title('#ticket by platform')
# Out:
# Text(0.5, 1.0, '#ticket by platform')

# %% [markdown]
# In general, the majority of the tickets come from mobile. There is a small number of tickets that our system could not identify which platform. However, those number are small and won't impact our analysis.

# %%
#By time
df_platform_time = (
    df_join_all[df_join_all['platform'] != 'unknown']
    .groupby(['year_month', 'platform'])
    .agg(total_ticket = ('ticket_id', 'count'))
    .sort_values(by='year_month', ascending=True).reset_index()
)

# %%
df_platform_time.head(5)
# Out:
#   year_month platform  total_ticket
# 0    2019-01   mobile          2389
# 1    2019-02   mobile          2018
# 2    2019-03   mobile          1290
# 3    2019-04   mobile          4346
# 4    2019-05   mobile          4816
